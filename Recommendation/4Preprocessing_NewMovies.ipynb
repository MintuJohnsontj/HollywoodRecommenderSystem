# %% [markdown]
# # MOVIES OF 2021

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the Data

# %%
def get_wikipedia(link, start, stop): # Start and stop are the range of required tables from wiki
    df = pd.DataFrame()
    for i in range(start, stop+1):
        df1 = pd.read_html(link, header=0)[i]
        df = df.append(df1, ignore_index=True)
    return df

link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"
df_2021 = get_wikipedia(link, 3, 4) # Get 3rd and 4th tables from the given Wikipedia page
df_2021
# Out:
#      Opening  Opening.1                        Title  \
# 0    JANUARY          1          Shadow in the Cloud
# 1    JANUARY         13              The White Tiger
# 2    JANUARY         14                  Locked Down
# 3    JANUARY         15                      The Dig
# 4    JANUARY         15             Outside the Wire
# ..       ...        ...                          ...
# 140     JUNE         25      Mary J. Blige's My Life
# 141     JUNE         25                       Fathom
# 142     JUNE         25                      Rollers
# 143     JUNE         30  America: The Motion Picture
# 144     JUNE         30                         Zola
#
#                      Production company  \
# 0                Vertical Entertainment
# 1                               Netflix
# 2       HBO Max / Warner Bros. Pictures
# 3           Netflix / Clerkenwell Films
# 4                               Netflix
# ..                                  ...
# 140                  Amazon Prime Video
# 141                           Apple TV+
# 142              Level 33 Entertainment
# 143  Netflix / Floyd County Productions
# 144                                 A24
#
#                                          Cast and crew  Ref   Ref.
# 0    Roseanne Liang (director/screenplay); Max Land...  [2]    NaN
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...  NaN    NaN
# 2    Doug Liman (director); Steven Knight (screenpl...  [3]    NaN
# 3    Simon Stone (director); Moira Buffini (screenp...  [4]    NaN
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...  [5]    NaN
# ..                                                 ...  ...    ...
# 140  Vanessa Roth (director/screenplay); Mary J. Bl...  NaN    NaN
# 141  Drew Xanthopoulos (director/screenplay); Miche...  NaN    NaN
# 142  Isaiah Smallman (director); Johnny Ray Gill, K...  NaN    NaN
# 143  Matt Thompson (director); Dave Callaham (scree...  NaN    NaN
# 144  Janicza Bravo (director/screenplay); Jeremy O....  NaN  [103]
#
# [145 rows x 7 columns]

# %%
df_2021 = df_2021[['Title','Cast and crew']]
df_2021
# Out:
#                            Title  \
# 0            Shadow in the Cloud
# 1                The White Tiger
# 2                    Locked Down
# 3                        The Dig
# 4               Outside the Wire
# ..                           ...
# 140      Mary J. Blige's My Life
# 141                       Fathom
# 142                      Rollers
# 143  America: The Motion Picture
# 144                         Zola
#
#                                          Cast and crew
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 140  Vanessa Roth (director/screenplay); Mary J. Bl...
# 141  Drew Xanthopoulos (director/screenplay); Miche...
# 142  Isaiah Smallman (director); Johnny Ray Gill, K...
# 143  Matt Thompson (director); Dave Callaham (scree...
# 144  Janicza Bravo (director/screenplay); Jeremy O....
#
# [145 rows x 2 columns]

# %% [markdown]
# # Feature Engineering

# %%
from tmdbv3api import TMDb
from tmdbv3api import Movie
tmdb = TMDb()
tmdb_movie = Movie() 
tmdb.api_key = 'be2a7f4d61b7fcfa93ac4a9f775e038d'

import json
import requests

def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))
df_2021
# Out:
# <ipython-input-5-0207a1eca214>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))
#                            Title  \
# 0            Shadow in the Cloud
# 1                The White Tiger
# 2                    Locked Down
# 3                        The Dig
# 4               Outside the Wire
# ..                           ...
# 140      Mary J. Blige's My Life
# 141                       Fathom
# 142                      Rollers
# 143  America: The Motion Picture
# 144                         Zola
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 140  Vanessa Roth (director/screenplay); Mary J. Bl...
# 141  Drew Xanthopoulos (director/screenplay); Miche...
# 142  Isaiah Smallman (director); Johnny Ray Gill, K...
# 143  Matt Thompson (director); Dave Callaham (scree...
# 144  Janicza Bravo (director/screenplay); Jeremy O....
#
#                                       genres
# 0                          Horror Action War
# 1                                Crime Drama
# 2                         Comedy Crime Drama
# 3                              Drama History
# 4            Thriller Action Science Fiction
# ..                                       ...
# 140                        Documentary Music
# 141                              Documentary
# 142                                   Comedy
# 143  Action Comedy History Animation Fantasy
# 144                       Drama Comedy Crime
#
# [145 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])
    
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))
df_2021
# Out:
# <ipython-input-7-0c937e21d4f5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
# <ipython-input-7-0c937e21d4f5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))
# <ipython-input-7-0c937e21d4f5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
#                            Title  \
# 0            Shadow in the Cloud
# 1                The White Tiger
# 2                    Locked Down
# 3                        The Dig
# 4               Outside the Wire
# ..                           ...
# 140      Mary J. Blige's My Life
# 141                       Fathom
# 142                      Rollers
# 143  America: The Motion Picture
# 144                         Zola
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 140  Vanessa Roth (director/screenplay); Mary J. Bl...
# 141  Drew Xanthopoulos (director/screenplay); Miche...
# 142  Isaiah Smallman (director); Johnny Ray Gill, K...
# 143  Matt Thompson (director); Dave Callaham (scree...
# 144  Janicza Bravo (director/screenplay); Jeremy O....
#
#                                       genres      director_name  \
# 0                          Horror Action War     Roseanne Liang
# 1                                Crime Drama      Ramin Bahrani
# 2                         Comedy Crime Drama         Doug Liman
# 3                              Drama History        Simon Stone
# 4            Thriller Action Science Fiction    Mikael Håfström
# ..                                       ...                ...
# 140                        Documentary Music       Vanessa Roth
# 141                              Documentary  Drew Xanthopoulos
# 142                                   Comedy    Isaiah Smallman
# 143  Action Comedy History Animation Fantasy      Matt Thompson
# 144                       Drama Comedy Crime      Janicza Bravo
#
#                                     actor_1_name       actor_2_name  \
# 0                             Chloë Grace Moretz  Taylor John Smith
# 1                                  Adarsh Gourav      Rajkummar Rao
# 2                                  Anne Hathaway   Chiwetel Ejiofor
# 3                                 Carey Mulligan      Ralph Fiennes
# 4                                 Anthony Mackie       Damson Idris
# ..                                           ...                ...
# 140                                Mary J. Blige   Taraji P. Henson
# 141                             Michelle Fournet      Ellen Garland
# 142  Isaiah Smallman (director); Johnny Ray Gill          Kate Cobb
# 143                               Channing Tatum   Jason Mantzoukas
# 144                                Taylour Paige       Riley Keough
#
#               actor_3_name
# 0             Beulah Koale
# 1    Priyanka Chopra Jonas
# 2         Stephen Merchant
# 3               Lily James
# 4            Emily Beecham
# ..                     ...
# 140            Alicia Keys
# 141                    NaN
# 142            Vicky Jeudy
# 143            Olivia Munn
# 144         Nicholas Braun
#
# [145 rows x 7 columns]

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df21
# Out:
#          director_name                                 actor_1_name  \
# 0       Roseanne Liang                           Chloë Grace Moretz
# 1        Ramin Bahrani                                Adarsh Gourav
# 2           Doug Liman                                Anne Hathaway
# 3          Simon Stone                               Carey Mulligan
# 4      Mikael Håfström                               Anthony Mackie
# ..                 ...                                          ...
# 140       Vanessa Roth                                Mary J. Blige
# 141  Drew Xanthopoulos                             Michelle Fournet
# 142    Isaiah Smallman  Isaiah Smallman (director); Johnny Ray Gill
# 143      Matt Thompson                               Channing Tatum
# 144      Janicza Bravo                                Taylour Paige
#
#           actor_2_name           actor_3_name  \
# 0    Taylor John Smith           Beulah Koale
# 1        Rajkummar Rao  Priyanka Chopra Jonas
# 2     Chiwetel Ejiofor       Stephen Merchant
# 3        Ralph Fiennes             Lily James
# 4         Damson Idris          Emily Beecham
# ..                 ...                    ...
# 140   Taraji P. Henson            Alicia Keys
# 141      Ellen Garland                    NaN
# 142          Kate Cobb            Vicky Jeudy
# 143   Jason Mantzoukas            Olivia Munn
# 144       Riley Keough         Nicholas Braun
#
#                                       genres                  movie_title
# 0                          Horror Action War          Shadow in the Cloud
# 1                                Crime Drama              The White Tiger
# 2                         Comedy Crime Drama                  Locked Down
# 3                              Drama History                      The Dig
# 4            Thriller Action Science Fiction             Outside the Wire
# ..                                       ...                          ...
# 140                        Documentary Music      Mary J. Blige's My Life
# 141                              Documentary                       Fathom
# 142                                   Comedy                      Rollers
# 143  Action Comedy History Animation Fantasy  America: The Motion Picture
# 144                       Drama Comedy Crime                         Zola
#
# [145 rows x 6 columns]

# %% [markdown]
# # Handling the Null values

# %%
new_df21.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     8
# genres           1
# movie_title      0
# dtype: int64

# %%
new_df21 = new_df21.dropna(how='any')
new_df21.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# dtype: int64

# %%
new_df21['movie_title'] = new_df21['movie_title'].str.lower()
new_df21
# Out:
# <ipython-input-12-134d4eec74f2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df21['movie_title'] = new_df21['movie_title'].str.lower()
#        director_name                                 actor_1_name  \
# 0     Roseanne Liang                           Chloë Grace Moretz
# 1      Ramin Bahrani                                Adarsh Gourav
# 2         Doug Liman                                Anne Hathaway
# 3        Simon Stone                               Carey Mulligan
# 4    Mikael Håfström                               Anthony Mackie
# ..               ...                                          ...
# 139      Heidi Ewing                              Armando Espitia
# 140     Vanessa Roth                                Mary J. Blige
# 142  Isaiah Smallman  Isaiah Smallman (director); Johnny Ray Gill
# 143    Matt Thompson                               Channing Tatum
# 144    Janicza Bravo                                Taylour Paige
#
#           actor_2_name           actor_3_name  \
# 0    Taylor John Smith           Beulah Koale
# 1        Rajkummar Rao  Priyanka Chopra Jonas
# 2     Chiwetel Ejiofor       Stephen Merchant
# 3        Ralph Fiennes             Lily James
# 4         Damson Idris          Emily Beecham
# ..                 ...                    ...
# 139  Christian Vázquez     Michelle Rodríguez
# 140   Taraji P. Henson            Alicia Keys
# 142          Kate Cobb            Vicky Jeudy
# 143   Jason Mantzoukas            Olivia Munn
# 144       Riley Keough         Nicholas Braun
#
#                                       genres                  movie_title
# 0                          Horror Action War          shadow in the cloud
# 1                                Crime Drama              the white tiger
# 2                         Comedy Crime Drama                  locked down
# 3                              Drama History                      the dig
# 4            Thriller Action Science Fiction             outside the wire
# ..                                       ...                          ...
# 139                            Drama Romance          i carry you with me
# 140                        Documentary Music      mary j. blige's my life
# 142                                   Comedy                      rollers
# 143  Action Comedy History Animation Fantasy  america: the motion picture
# 144                       Drama Comedy Crime                         zola
#
# [136 rows x 6 columns]

# %% [markdown]
# # Save the File

# %%
new_df21.to_csv("prep4data.csv", index=False)
